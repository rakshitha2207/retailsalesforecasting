# %%
import pandas as pd
import importlib
from BuildTsModel import (
    evaluate_forecast, residcheck, calculate_pi_difference
)
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pmdarima as pm
from statsmodels.tsa.arima_model import ARIMA
# set plot style to ggplot2
plt.style.use('ggplot')
# maximize the size of the labels, ticks, and figures
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
# legend settings
plt.rcParams['legend.fontsize'] = 10

# %%
# import the training and testing data
train = pd.read_csv('train.csv', index_col=0, parse_dates=True)
train = train.squeeze()
train.index.freq = 'MS'
test = pd.read_csv('test.csv', index_col=0, parse_dates=True)
test = test.squeeze()
test.index.freq = 'MS'

# %% [markdown]
# # SARIMA (Seasonal, Auto-Regressive, Integrated, Moving Average Model)

# %%
train_trend_diff = train.diff(1).dropna()
train_seasoanl_diff = train_trend_diff.diff(12)
train_seasoanl_diff.dropna(inplace=True)

# %%
plt.plot(train_seasoanl_diff, label='Time series of the lag-12 difference of the once-differenced sales')
plt.legend()
plt.show()

# %%
#Check for stationarity
result = sm.tsa.stattools.adfuller(train_seasoanl_diff, autolag= 'AIC')
if result[1] < 0.05:
    print('Time series is stationary')
else:
    print('Time series is not stationary')
# Out:
# Time series is stationary

# %%
fig, ax = plt.subplots(2, figsize=(8,12))
sm.graphics.tsa.plot_acf(train_seasoanl_diff , lags=25, ax=ax[0])
sm.graphics.tsa.plot_pacf(train_seasoanl_diff , lags=25, ax=ax[1])
plt.show()

# %%
# Fit the model using auto_arima
model = pm.auto_arima(train, 
                      test='adf',       # use the ADF test to find best order of integration
                      max_p=3, max_q=3, # maximum p and q
                      m=12,             # frequency of series (12 for monthly data)
                      seasonal=True,    # allow for seasonality
                      start_P=0,        # starting value of seasonal order
                      trace=True,       # print diagnostic information
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,    # use a stepwise algorithm to speed up fitting
                      information_criterion='aic', # Select based on AIC
                      enforce_stationarity=False,  # don't enforce stationarity
                      enforce_invertibility=False  # don't enforce invertibility
                     )

# Print the model summary
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=3284.425, Time=1.16 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=3747.680, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=3294.104, Time=0.46 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=3745.825, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=3509.289, Time=0.45 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=2887.815, Time=2.40 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=2954.747, Time=1.50 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=5.47 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=5.26 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=3141.526, Time=4.39 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=2836.864, Time=4.18 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=2880.581, Time=4.54 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=2852.732, Time=8.04 sec
#  ARIMA(3,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=nan sec
#  ARIMA(2,1,3)(2,0,0)[12] intercept   : AIC=inf, Time=10.98 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=7.57 sec
#  ARIMA(1,1,3)(2,0,0)[12] intercept   : AIC=2864.353, Time=7.08 sec
#  ARIMA(3,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=9.69 sec
#  ARIMA(3,1,3)(2,0,0)[12] intercept   : AIC=inf, Time=10.97 sec
#  ARIMA(2,1,2)(2,0,0)[12]             : AIC=2852.152, Time=2.64 sec
#
# Best model:  ARIMA(2,1,2)(2,0,0)[12] intercept
# Total fit time: 96.166 seconds
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  352
# Model:             SARIMAX(2, 1, 2)x(2, 0, [], 12)   Log Likelihood               -1410.432
# Date:                             Tue, 05 Nov 2024   AIC                           2836.864
# Time:                                     21:23:00   BIC                           2867.751
# Sample:                                 01-01-1992   HQIC                          2849.157
#                                       - 04-01-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.4126      1.044      0.395      0.693      -1.634       2.459
# ar.L1         -1.1505      0.010   -119.054      0.000      -1.169      -1.132
# ar.L2         -0.9875      0.008   -118.236      0.000      -1.004      -0.971
# ma.L1          1.0903      0.025     43.435      0.000       1.041       1.140
# ma.L2          0.9208      0.027     33.602      0.000       0.867       0.974
# ar.S.L12       0.4354      0.038     11.396      0.000       0.361       0.510
# ar.S.L24       0.5432      0.038     14.379      0.000       0.469       0.617
# sigma2       162.3918      7.799     20.822      0.000     147.106     177.677
# ===================================================================================
# Ljung-Box (L1) (Q):                  15.88   Jarque-Bera (JB):              1310.93
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.10   Skew:                             0.92
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# models hyperparameters
p, d, q = 0, 1, 2
P, D, Q, m = 0, 1, 1, 12
model = sm.tsa.statespace.SARIMAX(train, order=(p, d, q), seasonal_order=(P, D, Q, m),
                                  enforce_stationarity=False,
                                enforce_invertibility=False)
results = model.fit()
print(results.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                         sales_amount   No. Observations:                  352
# Model:             SARIMAX(0, 1, 2)x(0, 1, [1], 12)   Log Likelihood               -1280.960
# Date:                              Tue, 05 Nov 2024   AIC                           2569.920
# Time:                                      21:23:01   BIC                           2585.043
# Sample:                                  01-01-1992   HQIC                          2575.957
#                                        - 04-01-2021
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4518      0.027    -16.804      0.000      -0.505      -0.399
# ma.L2         -0.0851      0.028     -3.018      0.003      -0.140      -0.030
# ma.S.L12      -0.8467      0.034    -24.882      0.000      -0.913      -0.780
# sigma2       154.9790      5.847     26.505      0.000     143.519     166.439
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):               843.32
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.16   Skew:                             0.52
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # SARIMAX diagnostic tests

# %%
residcheck(results.resid, 12)
# Out:
# ** Mean of the residuals:  0.49
#
# ** Ljung Box Test, p-value: 0.492 (>0.05, Uncorrelated)
#
# ** Jarque Bera Normality Test, p_value: 0.0 (<0.05, Not-normal)
#
# ** AD Fuller, p_value: 0.0 (<0.05, Stationary)
# (<Axes: >,
#  <Axes: title={'center': 'Autocorrelation'}>,
#  <Axes: ylabel='Density'>)

# %%
# Perform diagnostic tests on the residuals
results.plot_diagnostics(figsize=(15, 12), lags=24)
plt.show()

# %%
# Get the forecast
forecast = results.get_forecast(steps=len(test))

# Get the confidence intervals
forecast_ci = forecast.conf_int(0.95)

# Plot the forecast and the confidence intervals
fig, ax = plt.subplots()
ax.plot(train.index, train, label='Train', color='blue')
ax.plot(results.fittedvalues.index, results.fittedvalues, label='Fitted values', color='red')
ax.plot(test.index, test, label='Test', color='green')
ax.plot(forecast.predicted_mean.index, forecast.predicted_mean, label='Forecast', color='black')
ax.fill_between(forecast_ci.index,
                forecast_ci.iloc[:, 0],
                forecast_ci.iloc[:, 1], color='k', alpha=.25, label='95% Confidence interval')

# Set the axis labels and legend
plt.title("Real Advance Retail Sales in US: Retail Trade (SARIMAX Results)", color='black', weight='bold')
ax.set_xlabel('Month', color='black', weight='bold')
ax.set_ylabel('Billions of 2023 Dollars', color='black', weight='bold')
# bold the legend font
legend = ax.legend(loc='upper left')
for label in legend.get_texts():
    label.set_fontweight('bold')
plt.show()

# %%
# Plot the forecast and the confidence intervals
fig, ax = plt.subplots()
ax.plot(test.index, test, label='Test', color='green')
ax.plot(forecast.predicted_mean.index, forecast.predicted_mean, label='Forecast', color='black')
ax.fill_between(forecast_ci.index,
                forecast_ci.iloc[:, 0],
                forecast_ci.iloc[:, 1], color='k', alpha=.25, label='95% Confidence interval (CI)')

# Set the axis labels and legend
plt.title("Real Advance Retail Sales in US: Retail Trade (SARIMAX Results)", color='black', weight='bold')
ax.set_xlabel('Month', color='black', weight='bold')
ax.set_ylabel('Billions of 2023 Dollars', color='black', weight='bold')
# bold the legend font
legend = ax.legend(loc='upper left')
for label in legend.get_texts():
    label.set_fontweight('bold')
plt.show()

# %%
evaluate_forecast('SARIMAX', test, forecast.predicted_mean)
# Out:
# {'Model': 'SARIMAX', 'MAE': 53.6787, 'RMSE': 60.3387, 'MAPE': 8.6841}

# %%
# check the coverage of the predicted intervals for testing set
calculate_pi_difference(test, forecast_ci)
# Out:
# {'coverage': 0.78,
#  'coverage_description': 'The proportion of true values within the confidence interval.',
#  'ci_width': 4900.763,
#  'ci_width_description': 'The width of the confidence interval, which indicates the uncertainty of the forecast.'}
